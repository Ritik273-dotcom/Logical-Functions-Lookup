# %% [markdown]
# Question 1: Write a formula to check if the marks in cell are greater than or equal to 40. If yes, return "Pass", otherwise "Fail".
#
# Answer: ![image.png](data:image/png;base64,...)
#
# Formula: =IF(B11>=40,"Pass", "Fail")

# %% [markdown]
# Question 2: A company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not.
#
# Answer: ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 3: Write a nested IF formula:
#
# If marks in are ≥ 90 → , ≥ 75 → , ≥ 50 → , otherwise . B2 "A" "B" "C" "Fail"
#
# Answer: ![image.png](data:image/png;base64,...)
#
# Formula: =IFS(O5>=90, "A", O5>=75, "B",O5>=50, "C")

# %% [markdown]
# Question 4: Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
#
# Answer: ![image.png](data:image/png;base64,...)
#
# Function used: =LOOKUP(Q12,N12:N16,P12:P16)

# %% [markdown]
# Question 5: A company has set the following commission structure for its sales team:
#
# If a salesperson achieves sales of ₹45,000, use the VLOOKUP function to determine the commission rate
# applicable.
#
# Answer: ![image.png](data:image/png;base64,...)
#
# Formula: =VLOOKUP(R24,$O$21:$P$25,2,TRUE)

# %% [markdown]
# Question 6: The HR department maintains the following leave records of employees:onus or not .
#
# Write an IF function to check whether an employee has Exceeded their allowed leave balance.
#
# If Leaves Taken > Allowed Leaves, display "Exceeded".
#
# Otherwise, display "OK".
#
# Answer: ![image.png](data:image/png;base64,...)

# %% [markdown]
# Question 7: Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
# Answer: ![image.png](data:image/png;base64,...)
#
# Formula: =INDEX(K37:K40,MATCH("E105",J37:J40,0))

# %% [markdown]
# Question 8: U se the XLOOKUP function to find the Department of the employee with Emp ID = E303.
#
# Answer: ![image.png](data:image/png;base64,...)
#
# Formula: =XLOOKUP(L42,J43:J46,K43:K46, "Not Found",0 )
